# %%
! pip install torchtext
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchtext
#   Downloading torchtext-0.18.0-cp312-cp312-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in c:\users\anton\appdata\roaming\python\python312\site-packages (from torchtext) (4.67.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from torchtext) (2.32.2)
# Requirement already satisfied: torch>=2.3.0 in c:\users\anton\appdata\roaming\python\python312\site-packages (from torchtext) (2.9.1+cu130)
# Requirement already satisfied: numpy in c:\users\anton\appdata\roaming\python\python312\site-packages (from torchtext) (2.2.6)
# Requirement already satisfied: filelock in c:\users\anton\appdata\roaming\python\python312\site-packages (from torch>=2.3.0->torchtext) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\anton\appdata\roaming\python\python312\site-packages (from torch>=2.3.0->torchtext) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\anton\appdata\roaming\python\python312\site-packages (from torch>=2.3.0->torchtext) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\anton\appdata\roaming\python\python312\site-packages (from torch>=2.3.0->torchtext) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\anton\appdata\roaming\python\python312\site-packages (from torch>=2.3.0->torchtext) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\anton\appdata\roaming\python\python312\site-packages (from torch>=2.3.0->torchtext) (2025.12.0)
# Requirement already satisfied: setuptools in c:\users\anton\appdata\roaming\python\python312\site-packages (from torch>=2.3.0->torchtext) (70.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->torchtext) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->torchtext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->torchtext) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->torchtext) (2026.1.4)
# Requirement already satisfied: colorama in c:\users\anton\appdata\roaming\python\python312\site-packages (from tqdm->torchtext) (0.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anton\appdata\roaming\python\python312\site-packages (from sympy>=1.13.3->torch>=2.3.0->torchtext) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anton\appdata\roaming\python\python312\site-packages (from jinja2->torch>=2.3.0->torchtext) (2.1.5)
# Downloading torchtext-0.18.0-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------- ------------------------------- 0.4/2.0 MB 8.9 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.0 MB 10.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/2.0 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  1.9/2.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: torchtext
# Successfully installed torchtext-0.18.0

# %%
import torchtext
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\_ops.py:1488, in _Ops.load_library(self, path)
#    1487 try:
# -> 1488     ctypes.CDLL(path)
#    1489 except Exception as e:
#
# File C:\ProgramData\anaconda3\Lib\ctypes\__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#
# OSError: [WinError 127] Não foi possível encontrar o procedimento especificado
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torchtext
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torchtext\__init__.py:18
#      15     _WARN = False
#      17 # the following import has to happen first in order to load the torchtext C++ library
# ---> 18 from torchtext import _extension  # noqa: F401
#      20 _TEXT_BUCKET = "https://download.pytorch.org/models/text/"
#      22 _CACHE_DIR = os.path.expanduser(os.path.join(_get_torch_home(), "text"))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torchtext\_extension.py:64
#      59     # This import is for initializing the methods registered via PyBind11
#      60     # This has to happen after the base library is loaded
#      61     from torchtext import _torchtext  # noqa
# ---> 64 _init_extension()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torchtext\_extension.py:58, in _init_extension()
#      55 if not _mod_utils.is_module_available("torchtext._torchtext"):
#      56     raise ImportError("torchtext C++ Extension is not found.")
# ---> 58 _load_lib("libtorchtext")
#      59 # This import is for initializing the methods registered via PyBind11
#      60 # This has to happen after the base library is loaded
#      61 from torchtext import _torchtext
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torchtext\_extension.py:50, in _load_lib(lib)
#      48 if not path.exists():
#      49     return False
# ---> 50 torch.ops.load_library(path)
#      51 return True
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\_ops.py:1490, in _Ops.load_library(self, path)
#    1488         ctypes.CDLL(path)
#    1489     except Exception as e:
# -> 1490         raise OSError(f"Could not load this library: {path}") from e
#    1491 self.loaded_libraries.add(path)
#
# OSError: Could not load this library: C:\Users\anton\AppData\Roaming\Python\Python312\site-packages\torchtext\lib\libtorchtext.pyd

# %%
texto = """rato roeu a roupa do rei de Roma,
O rato roeu a roupa do rei da Rússia,
O rato roeu a roupa do RodovaIho...
O rato a roer roía
E a rosa Rita Ramalho do rato a roer se ria.
O rato roeu a roupa do rei de roma
a rainha com raiva roeu o resto."""

# %%
counter =  collections.Counter()
for (label, line) in train_dataset:
    counter.update(tokenizer(line))

vocab = torchtext.vocab.vocab(counter, min_freq=1)
