# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
macas = [12, 15, 18, 13, 20]

# %%
s1 = pd.Series( macas, name="Macas" )
s1
# Out:
# 0    12
# 1    15
# 2    18
# 3    13
# 4    20
# Name: Macas, dtype: int64

# %%
s2 = pd.Series( [9, 16, 11, 15, 18], name="Peras" )
s2
# Out:
# 0     9
# 1    16
# 2    11
# 3    15
# 4    18
# Name: Peras, dtype: int64

# %%
df = pd.DataFrame( pd.concat( [s1, s2], axis=1 ) )
df
# Out:
#    Macas  Peras
# 0     12      9
# 1     15     16
# 2     18     11
# 3     13     15
# 4     20     18

# %%
dicionario = { "Macas": [12, 15, 18, 13, 20], "Peras": [9, 16, 11, 15, 18] }

# %%
df = pd.DataFrame( dicionario, index = ["Joao", "Maria", "Paulo", "Eduarda", "Olimpio"] )
df
# Out:
#          Macas  Peras
# Joao        12      9
# Maria       15     16
# Paulo       18     11
# Eduarda     13     15
# Olimpio     20     18

# %%
df.loc["Paulo"]
# Out:
# Macas    18
# Peras    11
# Name: Paulo, dtype: int64

# %%
df.iloc[ 3 ]
# Out:
# Macas    13
# Peras    15
# Name: Eduarda, dtype: int64

# %%
df.loc["Paulo"]["Macas"]
# Out:
# np.int64(18)

# %%
df.loc["Paulo"]["Peras"]
# Out:
# np.int64(11)

# %%
# df2 = pd.DataFrame.from_dict( dicionario, orient="index", columns = ["Jan", "Fev", "Mar", "Abr", ] )
dicionario = { "Macas": [12, 15, 18, 13, 20], "Peras": [9, 16, 11, 15, 18] }
df2 = pd.DataFrame( dicionario, index = ["Jan", "Fev", "Mar", "Abr", "Mai"] )
df2
# Out:
#      Macas  Peras
# Jan     12      9
# Fev     15     16
# Mar     18     11
# Abr     13     15
# Mai     20     18

# %%
df2["Macas"]
# Out:
# Jan    12
# Fev    15
# Mar    18
# Abr    13
# Mai    20
# Name: Macas, dtype: int64

# %%
plt.plot(df2["Macas"], label="Macas")
plt.plot(df2["Peras"], label="Peras")
plt.legend()

# %%
# df3 = pd.read_csv( "C:\\git\\dados\\nlp\\medium_data.csv", encoding = "utf-8" )
df3 = pd.read_csv( "C:\\git\\dados\\nlp\\medium_data.csv", encoding = "utf-8", index_col = 0  )
df3
# Out:
#                                                     url  \
# id
# 1     https://towardsdatascience.com/a-beginners-gui...
# 2     https://towardsdatascience.com/hands-on-graph-...
# 3     https://towardsdatascience.com/how-to-use-ggpl...
# 4     https://towardsdatascience.com/databricks-how-...
# 5     https://towardsdatascience.com/a-step-by-step-...
# ...                                                 ...
# 6504  https://medium.com/better-marketing/we-vs-i-ho...
# 6505  https://medium.com/better-marketing/how-donald...
# 6506  https://medium.com/better-marketing/content-an...
# 6507  https://medium.com/better-marketing/5-question...
# 6508  https://medium.com/better-marketing/how-to-wri...
#
#                                                   title  \
# id
# 1     A Beginner’s Guide to Word Embedding with Gens...
# 2     Hands-on Graph Neural Networks with PyTorch & ...
# 3                          How to Use ggplot2 in Python
# ...

# %%
df3.head(10)
# Out:
#    id                                                url  \
# 0   1  https://towardsdatascience.com/a-beginners-gui...
# 1   2  https://towardsdatascience.com/hands-on-graph-...
# 2   3  https://towardsdatascience.com/how-to-use-ggpl...
# 3   4  https://towardsdatascience.com/databricks-how-...
# 4   5  https://towardsdatascience.com/a-step-by-step-...
# 5   6  https://towardsdatascience.com/an-easy-introdu...
# 6   7  https://towardsdatascience.com/hypothesis-test...
# 7   8  https://towardsdatascience.com/introduction-to...
# 8   9  https://towardsdatascience.com/which-2020-cand...
# 9  10  https://towardsdatascience.com/what-if-ai-mode...
#
#                                                title  \
# 0  A Beginner’s Guide to Word Embedding with Gens...
# 1  Hands-on Graph Neural Networks with PyTorch & ...
# 2                       How to Use ggplot2 in Python
# 3  Databricks: How to Save Files in CSV on Your L...
# 4  A Step-by-Step Implementation of Gradient Desc...
# ...

# %%
df3.tail(3)
# Out:
#         id                                                url  \
# 6505  6506  https://medium.com/better-marketing/content-an...
# 6506  6507  https://medium.com/better-marketing/5-question...
# 6507  6508  https://medium.com/better-marketing/how-to-wri...
#
#                                                   title  \
# 6505      Content and Marketing Beyond Mass Consumption
# 6506  5 Questions All Copywriters Should Ask Clients...
# 6507             How To Write a Good Business Blog Post
#
#                                                subtitle     image  claps  \
# 6505  How to acquire customers without wasting money...  6506.jpg    207
# 6506                           Save time and effort by…  6507.jpg    253
# 6507                    An A-to-Z guide for non-writers  6508.jpg    147
#
#      responses  reading_time       publication        date
# 6505         1             8  Better Marketing  2019-12-05
# 6506         2             5  Better Marketing  2019-12-05
# ...

# %%
df3.describe()
# Out:
#                 id         claps  reading_time
# count  6508.000000   6508.000000   6508.000000
# mean   3254.500000    311.076060      6.134911
# std    1878.842108    950.789896      3.231918
# min       1.000000      0.000000      0.000000
# 25%    1627.750000     54.000000      4.000000
# 50%    3254.500000    115.000000      5.000000
# 75%    4881.250000    268.250000      7.000000
# max    6508.000000  38000.000000     55.000000

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6508 entries, 0 to 6507
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6508 non-null   int64
#  1   url           6508 non-null   object
#  2   title         6508 non-null   object
#  3   subtitle      3479 non-null   object
#  4   image         6361 non-null   object
#  5   claps         6508 non-null   int64
#  6   responses     6508 non-null   object
#  7   reading_time  6508 non-null   int64
#  8   publication   6508 non-null   object
#  9   date          6508 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 508.6+ KB
